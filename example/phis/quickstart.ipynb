# %% [markdown]
# # Phis Demo

# %%
from agroservices.phis.phis import Phis
phis = Phis()
# Out:
# WARNING [agroservices:Phis:116]:  The URL (https://phenome.inrae.fr/m3p/rest/) provided cannot be reached.

# %% [markdown]
# ## Authentification

# %%
token, status_code = phis.authenticate()

print(token)
print('-')
print(status_code)
# Out:
# eyJhbGciOiJSUzUxMiIsInR5cCI6IkpXVCJ9.....nbMnE5chzpWwwwXMP-Ls8mSU1qNvFOzo1kK9PXAJoArt2rDIa0-VmVww_J4iqV4YQVqJFh1d3DwsMVnqV0_iezOOuQFk4X4v6hC2uTFs_nT6dipCrWoF-IneK1WF6Bg782BzkN6-yGykglgdi2RqTEMIjC3Qe38EF17U8dMO604pRQvt9LOeD-iys_OiXv8pluHRIXJoRgmzHS_sxYTZgF_bTPTpayH2jeVXV8eUs-rxkydX8CwmpX3BHJXLjgYk9xlla1Hh5LsgTnWW3vGS7M_gzCfBeCB7YqdMcIU6nAO-HumfQimVSKpcDatblboBVtMVCo6Zw82-GskmkKkR5Q
# -
# 200

# %% [markdown]
# ## Navigate data

# %% [markdown]
# #### List available experiments

# %%
phis.get_experiment()
# Out:
# {'metadata': {'pagination': {'pageSize': 20,
#    'currentPage': 0,
#    'totalCount': 1,
#    'totalPages': 1,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'm3p:id/experiment/g2was2022',
#    'name': 'G2WAS2022',
#    'start_date': '2022-05-15',
#    'end_date': '2022-07-31',
#    'description': '',
#    'objective': 'G2WAS project',
#    'species': [],
#    'is_public': True,
#    'facilities': ['m3p:id/organization/facility.phenoarch',
#     'm3p:id/organization/facility.phenodyn']}]}

# %% [markdown]
# #### Get specific experiment with URI

# %%
phis.get_experiment(uri='m3p:id/experiment/g2was2022')
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'uri': 'm3p:id/experiment/g2was2022',
#   'publisher': None,
#   'publication_date': None,
#   'last_updated_date': None,
#   'name': 'G2WAS2022',
#   'start_date': '2022-05-15',
#   'end_date': '2022-07-31',
#   'description': '',
#   'objective': 'G2WAS project',
#   'species': [],
#   'factors': [],
#   'organisations': [{'uri': 'http://phenome.inrae.fr/id/organization/m3p',
#     'name': 'M3P',
#     'rdf_type': 'vocabulary:LocalOrganization',
#     'rdf_type_name': 'local organization',
#     'publication_date': None,
#     'last_updated_date': None},
#    {'uri': 'm3p:id/organization/phenoarch',
#     'name': 'PHENOARCH',
#     'rdf_type': 'vocabulary:LocalOrganization',
#     'rdf_type_name': 'local organization',
#     'publication_date': None,
# ...

# %% [markdown]
# #### List available variables

# %%
phis.get_variable()
# Out:
# {'metadata': {'pagination': {'pageSize': 100,
#    'currentPage': 0,
#    'totalCount': 18,
#    'totalPages': 1,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'http://phenome.inrae.fr/m3p/id/variable/ev000020',
#    'name': 'air humidity_weather station_percentage',
#    'entity': {'uri': 'm3p:id/variable/entity.air', 'name': 'Air'},
#    'entity_of_interest': None,
#    'characteristic': {'uri': 'm3p:id/variable/characteristic.humidity',
#     'name': 'humidity'},
#    'method': {'uri': 'm3p:id/variable/method.shelter_instant',
#     'name': 'Shelter_Instant_Measurement'},
#    'unit': {'uri': 'm3p:id/variable/unit.percentage', 'name': 'percent'},
#    'onLocal': False,
#    'sharedResourceInstance': None,
#    'alternative_name': None},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/ev000001',
#    'name': 'air temperature_weather station_degree celsius',
# ...

# %% [markdown]
# #### Get specific variable with URI

# %%
phis.get_variable(uri='http://phenome.inrae.fr/m3p/id/variable/ev000020')
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'uri': 'http://phenome.inrae.fr/m3p/id/variable/ev000020',
#   'name': 'air humidity_weather station_percentage',
#   'alternative_name': None,
#   'description': None,
#   'entity': {'uri': 'm3p:id/variable/entity.air', 'name': 'Air'},
#   'entity_of_interest': None,
#   'characteristic': {'uri': 'm3p:id/variable/characteristic.humidity',
#    'name': 'humidity'},
#   'trait': None,
#   'trait_name': None,
#   'method': {'uri': 'm3p:id/variable/method.shelter_instant',
#    'name': 'Shelter_Instant_Measurement'},
#   'unit': {'uri': 'm3p:id/variable/unit.percentage',
#    'name': 'percent',
#    'description': '"Percent" is a unit for \'Dimensionless Ratio\' expressed as  %',
#    'symbol': '%',
#    'alternative_symbol': None,
# ...

# %% [markdown]
# #### List available projects

# %%
phis.get_project()
# Out:
# {'metadata': {'pagination': {'pageSize': 100,
#    'currentPage': 0,
#    'totalCount': 20,
#    'totalPages': 1,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'm3p:id/project/amaizing',
#    'publisher': None,
#    'publication_date': '2024-02-19T14:59:50.71845+01:00',
#    'last_updated_date': None,
#    'name': 'Amaizing',
#    'shortname': None,
#    'start_date': '2011-01-10',
#    'end_date': '2011-01-10',
#    'description': 'http://www.amaizing.fr/⏎> Responsable scientifiqu…',
#    'objective': None,
#    'financial_funding': 'Agence Nationale de la Recherche (ANR)',
#    'website': None,
#    'related_projects': [],
#    'coordinators': ['m3p:id/user/person.franois.tardieu'],
#    'scientific_contacts': [],
#    'administrative_contacts': [],
#    'experiments': []},
#   {'uri': 'm3p:id/project/cawas',
#    'publisher': None,
#    'publication_date': '2024-02-19T15:02:03.738864+01:00',
# ...

# %% [markdown]
# #### Get specific project with URI

# %%
phis.get_project(uri='m3p:id/project/vitsec')
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'uri': 'm3p:id/project/vitsec',
#   'publisher': {'uri': 'http://www.phenome.inrae.fr/m3p/users#admin.opensilex',
#    'email': 'admin@opensilex.org',
#    'language': 'en',
#    'admin': True,
#    'first_name': 'Admin',
#    'last_name': 'OpenSilex',
#    'linked_person': 'http://www.phenome.inrae.fr/m3p/users#admin.opensilex/Person',
#    'enable': True,
#    'favorites': None},
#   'publication_date': '2024-02-19T15:30:43.433037+01:00',
#   'last_updated_date': None,
#   'name': 'VITSEC',
#   'shortname': None,
#   'start_date': '2010-01-01',
#   'end_date': '2012-12-31',
#   'description': 'Molecular bases of grapevine adaptation to water …',
#   'objective': None,
#   'financial_funding': 'Agence Nationale de la Recherche (ANR)',
#   'website': None,
# ...

# %% [markdown]
# #### List available facilities

# %%
phis.get_facility()
# Out:
# {'metadata': {'pagination': {'pageSize': 5,
#    'currentPage': 0,
#    'totalCount': 5,
#    'totalPages': 1,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'm3p:id/organization/facility.chambre-e',
#    'publisher': None,
#    'publication_date': None,
#    'last_updated_date': None,
#    'rdf_type': 'vocabulary:GrowthChamber',
#    'rdf_type_name': 'growth chamber',
#    'name': 'chambre E',
#    'organizations': [],
#    'sites': [],
#    'address': None,
#    'variableGroups': [],
#    'geometry': None,
#    'relations': []},
#   {'uri': 'm3p:id/organization/facility.phenoarch',
#    'publisher': None,
#    'publication_date': None,
#    'last_updated_date': None,
#    'rdf_type': 'vocabulary:Greenhouse',
#    'rdf_type_name': 'greenhouse',
#    'name': 'phenoarch',
#    'organizations': [],
#    'sites': [],
#    'address': None,
#    'variableGroups': [],
#    'geometry': None,
#    'relations': []},
# ...

# %% [markdown]
# #### Get specific facility with URI

# %%
phis.get_facility(uri='m3p:id/organization/facility.phenoarch')
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'uri': 'm3p:id/organization/facility.phenoarch',
#   'publisher': None,
#   'publication_date': None,
#   'last_updated_date': None,
#   'rdf_type': 'vocabulary:Greenhouse',
#   'rdf_type_name': 'greenhouse',
#   'name': 'phenoarch',
#   'organizations': [],
#   'sites': [],
#   'address': None,
#   'variableGroups': [],
#   'geometry': None,
#   'relations': []}}

# %% [markdown]
# #### List available germplasms

# %%
phis.get_germplasm()
# Out:
# {'metadata': {'pagination': {'pageSize': 100,
#    'currentPage': 0,
#    'totalCount': 1239,
#    'totalPages': 13,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'http://aims.fao.org/aos/agrovoc/c_4555',
#    'rdf_type': 'http://www.opensilex.org/vocabulary/oeso#Species',
#    'rdf_type_name': 'Species',
#    'name': 'apple tree',
#    'species': None,
#    'species_name': None,
#    'publisher': None,
#    'publication_date': None,
#    'last_updated_date': None},
#   {'uri': 'http://aims.fao.org/aos/agrovoc/c_29128',
#    'rdf_type': 'http://www.opensilex.org/vocabulary/oeso#Species',
#    'rdf_type_name': 'Species',
#    'name': 'banana',
#    'species': None,
#    'species_name': None,
#    'publisher': None,
#    'publication_date': None,
#    'last_updated_date': None},
#   {'uri': 'http://aims.fao.org/aos/agrovoc/c_3662',
#    'rdf_type': 'http://www.opensilex.org/vocabulary/oeso#Species',
# ...

# %% [markdown]
# #### Get specific germplasm with URI

# %%
phis.get_germplasm(uri='http://aims.fao.org/aos/agrovoc/c_1066')
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'uri': 'http://aims.fao.org/aos/agrovoc/c_1066',
#   'publisher': None,
#   'publication_date': None,
#   'last_updated_date': None,
#   'rdf_type': 'vocabulary:Species',
#   'rdf_type_name': 'Species',
#   'name': 'colza',
#   'synonyms': [],
#   'code': None,
#   'production_year': None,
#   'description': None,
#   'species': None,
#   'species_name': None,
#   'variety': None,
#   'variety_name': None,
#   'accession': None,
#   'accession_name': None,
#   'institute': None,
#   'website': None,
#   'has_parent_germplasm': None,
#   'has_parent_germplasm_m': None,
#   'has_parent_germplasm_f': None,
#   'metadata': None}}

# %% [markdown]
# #### List available devices

# %%
phis.get_device()
# Out:
# {'metadata': {'pagination': {'pageSize': 100,
#    'currentPage': 0,
#    'totalCount': 339,
#    'totalPages': 4,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'http://www.phenome-fppn.fr/m3p/ec1/2016/sa1600064',
#    'rdf_type': 'vocabulary:CO2Sensor',
#    'rdf_type_name': 'CO2 sensor',
#    'name': 'aria_co2_cE1',
#    'brand': 'ARIA',
#    'constructor_model': None,
#    'serial_number': None,
#    'person_in_charge': None,
#    'start_up': '2011-05-01',
#    'removal': None,
#    'relations': [{'property': 'vocabulary:measures',
#      'value': 'm3p:id/variable/ev000024',
#      'inverse': False}],
#    'description': None,
#    'publisher': None,
#    'publication_date': None,
#    'last_updated_date': None},
#   {'uri': 'http://www.phenome-fppn.fr/m3p/ec2/2016/sa1600073',
#    'rdf_type': 'vocabulary:CO2Sensor',
#    'rdf_type_name': 'CO2 sensor',
#    'name': 'aria_co2_cE2',
#    'brand': 'ARIA',
# ...

# %% [markdown]
# #### Get specific device with URI

# %%
phis.get_device(uri='http://www.phenome-fppn.fr/m3p/ec1/2016/sa1600064')
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'uri': 'http://www.phenome-fppn.fr/m3p/ec1/2016/sa1600064',
#   'rdf_type': 'vocabulary:CO2Sensor',
#   'rdf_type_name': 'CO2 sensor',
#   'name': 'aria_co2_cE1',
#   'brand': 'ARIA',
#   'constructor_model': None,
#   'serial_number': None,
#   'person_in_charge': None,
#   'start_up': '2011-05-01',
#   'removal': None,
#   'relations': [{'property': 'vocabulary:measures',
#     'value': 'm3p:id/variable/ev000024',
#     'inverse': False}],
#   'description': None,
#   'metadata': None,
#   'publisher': None,
#   'publication_date': None,
#   'last_updated_date': None}}

# %% [markdown]
# #### List available annotations

# %%
phis.get_annotation()
# Out:
# {'metadata': {'pagination': {'pageSize': 100,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': []}

# %% [markdown]
# #### Get specific annotation with URI

# %%
# No URIs

# %% [markdown]
# #### List available documents

# %%
phis.get_document()
# Out:
# {'metadata': {'pagination': {'pageSize': 20,
#    'currentPage': 0,
#    'totalCount': 3,
#    'totalPages': 1,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'm3p:id/document/test_isa_doc_post_deploy',
#    'publisher': None,
#    'publication_date': None,
#    'last_updated_date': None,
#    'identifier': None,
#    'rdf_type': 'vocabulary:ScientificDocument',
#    'rdf_type_name': 'Scientific Document',
#    'title': 'test isa doc post deploy',
#    'date': '2022-04-05',
#    'description': None,
#    'targets': [],
#    'authors': [],
#    'language': None,
#    'format': 'png',
#    'keywords': [],
#    'deprecated': True,
#    'source': None},
#   {'uri': 'm3p:id/document/test_isa_doc',
#    'publisher': None,
#    'publication_date': None,
#    'last_updated_date': None,
#    'identifier': None,
#    'rdf_type': 'vocabulary:ScientificDocument',
#    'rdf_type_name': 'Scientific Document',
# ...

# %% [markdown]
# #### Get specific document with URI

# %%
phis.get_document(uri='m3p:id/document/test_dataset')
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'uri': 'm3p:id/document/test_dataset',
#   'publisher': None,
#   'publication_date': '2023-08-22T11:46:26.204356+02:00',
#   'last_updated_date': '2023-08-22T11:53:27.395245+02:00',
#   'identifier': 'doi:10.82233/BFHMFT',
#   'rdf_type': 'vocabulary-dataverse:RechercheDataGouvDataset',
#   'rdf_type_name': 'RechercheDataGouv Dataset',
#   'title': 'Test_dataset',
#   'date': '2020-02-20',
#   'description': 'Test et démo connexion IRODS',
#   'targets': ['m3p:id/experiment/expe_test_opensilex_irods'],
#   'authors': ['http://www.phenome.inrae.fr/m3p/users#admin.opensilex/Person'],
#   'language': 'English',
#   'format': None,
#   'keywords': [],
#   'deprecated': True,
# ...

# %% [markdown]
# #### List available factors

# %%
phis.get_factor()
# Out:
# {'metadata': {'pagination': {'pageSize': 100,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': []}

# %% [markdown]
# #### Get specific factor with URI

# %%
# No URIs

# %% [markdown]
# #### List available organizations

# %%
phis.get_organization()
# Out:
# {'metadata': {'pagination': {'pageSize': 6,
#    'currentPage': 0,
#    'totalCount': 6,
#    'totalPages': 1,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'https://emphasis.plant-phenotyping.eu/',
#    'name': 'EMPHASIS',
#    'parents': [],
#    'children': ['http://www.phenome-fppn.fr'],
#    'rdf_type': 'vocabulary:EuropeanOrganization',
#    'rdf_type_name': 'european organization',
#    'publication_date': None,
#    'last_updated_date': '2024-02-02T15:44:25.716531+01:00'},
#   {'uri': 'm3p:id/organization/phenoarch',
#    'name': 'PHENOARCH',
#    'parents': ['http://phenome.inrae.fr/id/organization/m3p'],
#    'children': [],
#    'rdf_type': 'vocabulary:LocalOrganization',
#    'rdf_type_name': 'local organization',
#    'publication_date': None,
#    'last_updated_date': None},
#   {'uri': 'm3p:id/organization/phenodyn',
#    'name': 'PHENODYN',
# ...

# %% [markdown]
# #### Get specific organization with URI

# %%
phis.get_organization(uri='m3p:id/organization/phenoarch')
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'uri': 'm3p:id/organization/phenoarch',
#   'rdf_type': 'vocabulary:LocalOrganization',
#   'rdf_type_name': 'local organization',
#   'publisher': None,
#   'publication_date': None,
#   'last_updated_date': None,
#   'name': 'PHENOARCH',
#   'parents': [{'uri': 'http://phenome.inrae.fr/id/organization/m3p',
#     'name': 'M3P',
#     'rdf_type': 'vocabulary:LocalOrganization',
#     'rdf_type_name': 'local organization',
#     'publication_date': None,
#     'last_updated_date': None}],
#   'children': [],
#   'groups': [],
#   'facilities': [],
#   'sites': [],
#   'experiments': [{'uri': 'm3p:id/experiment/dyn2020-05-15',
#     'name': 'G2WAS2020',
#     'rdf_type': 'vocabulary:Experiment',
#     'rdf_type_name': 'experiment',
#     'publication_date': None,
# ...

# %% [markdown]
# #### List available sites

# %%
phis.get_site()
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': []}

# %% [markdown]
# #### Get specific site with URI

# %%
# No URIs

# %% [markdown]
# #### List available scientific objects

# %%
phis.get_scientific_object()
# Out:
# {'metadata': {'pagination': {'pageSize': 100,
#    'currentPage': 0,
#    'totalCount': 3661,
#    'totalPages': 37,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'm3p:id/scientific-object/za20/so-0001zm4531eppn7_lwd1eppn_rep_101_01arch2020-02-03',
#    'name': '0001/ZM4531/EPPN7_L/WD1/EPPN_Rep_1/01_01/ARCH2020-02-03',
#    'geometry': None,
#    'rdf_type': 'vocabulary:Plant',
#    'rdf_type_name': 'plant',
#    'publication_date': None,
#    'last_updated_date': None,
#    'creation_date': None,
#    'destruction_date': None},
#   {'uri': 'm3p:id/scientific-object/za20/so-0002zm4534eppn10_lwd1eppn_rep_101_02arch2020-02-03',
#    'name': '0002/ZM4534/EPPN10_L/WD1/EPPN_Rep_1/01_02/ARCH2020-02-03',
#    'geometry': None,
#    'rdf_type': 'vocabulary:Plant',
#    'rdf_type_name': 'plant',
#    'publication_date': None,
#    'last_updated_date': None,
#    'creation_date': None,
#    'destruction_date': None},
# ...

# %% [markdown]
# #### Get specific scientific object with URI

# %%
phis.get_scientific_object(uri='m3p:id/scientific-object/za20/so-0001zm4531eppn7_lwd1eppn_rep_101_01arch2020-02-03')
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'uri': 'm3p:id/scientific-object/za20/so-0001zm4531eppn7_lwd1eppn_rep_101_01arch2020-02-03',
#   'publisher': None,
#   'publication_date': None,
#   'last_updated_date': None,
#   'rdf_type': 'vocabulary:Plant',
#   'rdf_type_name': 'plant',
#   'name': '0001/ZM4531/EPPN7_L/WD1/EPPN_Rep_1/01_01/ARCH2020-02-03',
#   'parent': None,
#   'parent_name': None,
#   'factor_level': None,
#   'relations': [],
#   'geometry': None}}

# %% [markdown]
# #### List available characteristics

# %%
phis.get_characteristic()
# Out:
# {'metadata': {'pagination': {'pageSize': 100,
#    'currentPage': 0,
#    'totalCount': 8,
#    'totalPages': 1,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'http://phenome.inrae.fr/m3p/id/variable/characteristic..co2',
#    'name': 'CO2'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/characteristic.fresh_weight',
#    'name': 'fresh_weight'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/characteristic.humidity',
#    'name': 'humidity'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/characteristic..infra-red-radiation',
#    'name': 'Infra-red radiation'},
#   {'uri': 'http://www.ontology-of-units-of-measure.org/resource/om-2/Irradiance',
#    'name': 'Irradiance'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/characteristic.lightning',
#    'name': 'Lightning'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/characteristic.shading',
#    'name': 'Shading'},
# ...

# %% [markdown]
# #### Get specific characteristic with URI

# %%
phis.get_characteristic(uri='http://phenome.inrae.fr/m3p/id/variable/characteristic.humidity')
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'uri': 'http://phenome.inrae.fr/m3p/id/variable/characteristic.humidity',
#   'name': 'humidity',
#   'description': None,
#   'publisher': None,
#   'publication_date': None,
#   'last_updated_date': None,
#   'exact_match': [],
#   'close_match': [],
#   'broad_match': [],
#   'narrow_match': [],
#   'from_shared_resource_instance': None}}

# %% [markdown]
# #### List available entities

# %%
phis.get_entity()
# Out:
# {'metadata': {'pagination': {'pageSize': 100,
#    'currentPage': 0,
#    'totalCount': 6,
#    'totalPages': 1,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'http://phenome.inrae.fr/m3p/id/variable/entity.air',
#    'name': 'Air'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/entity.greenhouse',
#    'name': 'Greenhouse'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/entity.leaf',
#    'name': 'Leaf'},
#   {'uri': 'http://purl.obolibrary.org/obo/PO_0000003', 'name': 'Plant'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/entity.solar',
#    'name': 'Solar'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/entity.water',
#    'name': 'Water'}]}

# %% [markdown]
# #### Get specific entity with URI

# %%
phis.get_entity(uri='http://phenome.inrae.fr/m3p/id/variable/entity.solar')
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'uri': 'http://phenome.inrae.fr/m3p/id/variable/entity.solar',
#   'name': 'Solar',
#   'description': None,
#   'publisher': None,
#   'publication_date': None,
#   'last_updated_date': None,
#   'exact_match': [],
#   'close_match': [],
#   'broad_match': [],
#   'narrow_match': [],
#   'from_shared_resource_instance': None}}

# %% [markdown]
# #### List available entities of interest

# %%
phis.get_entity_of_interest()
# Out:
# {'metadata': {'pagination': {'pageSize': 100,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': []}

# %% [markdown]
# #### Get specific entity of interest with URI

# %%
# No URIs

# %% [markdown]
# #### List available methods

# %%
phis.get_method()
# Out:
# {'metadata': {'pagination': {'pageSize': 100,
#    'currentPage': 0,
#    'totalCount': 11,
#    'totalPages': 1,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'http://phenome.inrae.fr/m3p/id/variable/method.computation',
#    'name': 'Computation'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/method.lower-near-surface',
#    'name': 'Lower near-surface'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/method.measurement',
#    'name': 'Measurement'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/method.par', 'name': 'PAR'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/method.par_diffuse',
#    'name': 'PAR_Diffuse'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/method.par_direct',
#    'name': 'PAR_Direct'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/method.radiation_global',
#    'name': 'Radiation_Global'},
# ...

# %% [markdown]
# #### Get specific method with URI

# %%
phis.get_method(uri='http://phenome.inrae.fr/m3p/id/variable/method.measurement')
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'uri': 'http://phenome.inrae.fr/m3p/id/variable/method.measurement',
#   'name': 'Measurement',
#   'description': None,
#   'publisher': None,
#   'publication_date': None,
#   'last_updated_date': None,
#   'exact_match': [],
#   'close_match': [],
#   'broad_match': [],
#   'narrow_match': [],
#   'from_shared_resource_instance': None}}

# %% [markdown]
# #### List available units

# %%
phis.get_unit()
# Out:
# {'metadata': {'pagination': {'pageSize': 100,
#    'currentPage': 0,
#    'totalCount': 12,
#    'totalPages': 1,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'http://phenome.inrae.fr/m3p/id/variable/unit.boolean',
#    'name': 'Boolean'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/unit.celsius',
#    'name': 'degree celsius'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/unit.gram', 'name': 'gram'},
#   {'uri': 'http://qudt.org/vocab/unit/J-PER-M2', 'name': 'J-PER-M2'},
#   {'uri': 'http://qudt.org/vocab/unit/J', 'name': 'Joule'},
#   {'uri': 'http://qudt.org/vocab/unit/KiloGM', 'name': 'kilogram'},
#   {'uri': 'http://qudt.org/vocab/unit/MicroMOL-PER-M2-SEC',
#    'name': 'MicroMOL-PER-M2-SEC'},
#   {'uri': 'http://phenome.inrae.fr/m3p/id/variable/unit.micromole-per-square-metre-per-second',
#    'name': 'Micromole per square metre per_second'},
# ...

# %% [markdown]
# #### Get specific unit with URI

# %%
phis.get_unit(uri='http://qudt.org/vocab/unit/J')
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'uri': 'http://qudt.org/vocab/unit/J',
#   'name': 'Joule',
# ...

# %% [markdown]
# #### List available provenances

# %%
phis.get_provenance()
# Out:
# {'metadata': {'pagination': {'pageSize': 100,
#    'currentPage': 0,
#    'totalCount': 149,
#    'totalPages': 2,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'm3p:provenance/standard_provenance',
#    'name': 'standard_provenance',
#    'description': 'This provenance is used when there is no need to describe a specific provenance',
#    'prov_activity': None,
#    'prov_agent': [],
#    'publisher': None,
#    'issued': None,
#    'modified': None},
#   {'uri': 'm3p:Prov_air_humidity_weather_station_percentage_hr01_p',
#    'name': 'Prov_air humidity_weather station_percentage_hr01_p',
#    'description': 'acquisition of air humidity_weather station_percentage and hr01_p',
#    'prov_activity': [{'rdf_type': 'vocabulary:MeasuresAcquisition',
#      'uri': None,
#      'start_date': None,
#      'end_date': None,
#      'settings': None}],
#    'prov_agent': [{'uri': 'm3p:id/deviceAttribut/arch/2011/sa110001',
# ...

# %% [markdown]
# #### Get specific provenance with URI

# %%
phis.get_provenance(uri='http://www.phenome-fppn.fr/m3p/Prov_watering_WateringStation05_6l')
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'uri': 'http://www.phenome-fppn.fr/m3p/Prov_watering_WateringStation05_6l',
#   'name': 'Prov_watering_WateringStation05_6l',
#   'description': 'acquisition of WateringStation05 and 6l [2023-05-17__13-37-01]',
#   'prov_activity': [{'rdf_type': 'vocabulary:MeasuresAcquisition',
#     'uri': None,
#     'start_date': '2023-03-01T00:00:00Z',
#     'end_date': None,
#     'settings': None}],
#   'prov_agent': [{'uri': 'http://www.phenome-fppn.fr/m3p/2019/s19005',
#     'rdf_type': 'vocabulary:WeighingScale',
#     'settings': None},
#    {'uri': 'http://www.phenome-fppn.fr/m3p/2019/v1911',
#     'rdf_type': 'vocabulary:Station',
#     'settings': None},
#    {'uri': 'http://www.phenome-fppn.fr/m3p/2020/a20005',
#     'rdf_type': 'vocabulary:WateringPump',
# ...

# %% [markdown]
# #### List available datafiles

# %%
phis.get_datafile()
# Out:
# {'metadata': {'pagination': {'pageSize': 100,
#    'currentPage': 0,
#    'totalCount': 1,
#    'totalPages': 1,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'm3p:id/file/1597964400.af46ac07f735ced228cf181aa85ebced',
#    'rdf_type': 'vocabulary:Image',
#    'date': '2020-08-21T00:00:00.000+0100',
#    'timezone': None,
#    'target': 'm3p:id/scientific-object/za20/so-0001zm4531eppn7_lwd1eppn_rep_101_01arch2020-02-03',
#    'provenance': {'uri': 'm3p:provenance/standard_provenance',
#     'prov_used': None,
#     'prov_was_associated_with': None,
#     'settings': None,
#     'experiments': None},
#    'metadata': None,
#    'archive': None,
#    'filename': '7018.tar',
#    'publisher': None,
#    'issued': None}]}

# %% [markdown]
# #### Get specific datafile with URI

# %%
phis.get_datafile(uri='m3p:id/file/1597964400.af46ac07f735ced228cf181aa85ebced')
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'uri': 'm3p:id/file/1597964400.af46ac07f735ced228cf181aa85ebced',
#   'rdf_type': 'vocabulary:Image',
#   'date': '2020-08-21T00:00:00.000+0100',
#   'timezone': None,
#   'target': 'm3p:id/scientific-object/za20/so-0001zm4531eppn7_lwd1eppn_rep_101_01arch2020-02-03',
#   'provenance': {'uri': 'm3p:provenance/standard_provenance',
#    'prov_used': None,
#    'prov_was_associated_with': None,
#    'settings': None,
#    'experiments': None},
#   'metadata': None,
#   'archive': None,
#   'filename': '7018.tar',
#   'publisher': None,
#   'issued': None}}

# %% [markdown]
# #### List available species

# %%
phis.get_species()
# Out:
# {'metadata': {'pagination': {'pageSize': 14,
#    'currentPage': 0,
#    'totalCount': 14,
#    'totalPages': 1,
#    'limitCount': 0,
#    'hasNextPage': True},
#   'status': [],
#   'datafiles': []},
#  'result': [{'uri': 'http://aims.fao.org/aos/agrovoc/c_4555',
#    'name': 'apple tree'},
#   {'uri': 'http://aims.fao.org/aos/agrovoc/c_29128', 'name': 'banana'},
#   {'uri': 'http://aims.fao.org/aos/agrovoc/c_3662', 'name': 'barley'},
#   {'uri': 'http://aims.fao.org/aos/agrovoc/c_7951', 'name': 'bread wheat'},
#   {'uri': 'http://aims.fao.org/aos/agrovoc/c_1066', 'name': 'colza'},
#   {'uri': 'http://aims.fao.org/aos/agrovoc/c_7955', 'name': 'durum wheat'},
#   {'uri': 'http://aims.fao.org/aos/agrovoc/c_8283', 'name': 'grapevine'},
#   {'uri': 'http://aims.fao.org/aos/agrovoc/c_8504', 'name': 'maize'},
#   {'uri': 'http://aims.fao.org/aos/agrovoc/c_13199', 'name': 'Pearl millet'},
#   {'uri': 'http://aims.fao.org/aos/agrovoc/c_6116', 'name': 'poplar'},
# ...

# %% [markdown]
# #### Get system informations

# %%
phis.get_system_info()
# Out:
# {'metadata': {'pagination': {'pageSize': 0,
#    'currentPage': 0,
#    'totalCount': 0,
#    'totalPages': 0,
#    'limitCount': 0,
#    'hasNextPage': False},
#   'status': [],
#   'datafiles': []},
#  'result': {'title': 'OpenSILEX',
#   'version': '1.2.7-rdg',
#   'description': 'OpenSILEX is an ontology-driven Information System designed for life science data.',
#   'contact': {'name': 'OpenSILEX Team',
#    'email': 'opensilex-help@groupes.renater.fr',
#    'homepage': 'http://www.opensilex.org/'},
#   'license': {'name': 'GNU Affero General Public License v3',
#    'url': 'https://www.gnu.org/licenses/agpl-3.0.fr.html'},
#   'modules_version': [{'name': 'org.opensilex.server.ServerModule',
#     'version': '1.2.7-rdg'},
#    {'name': 'org.opensilex.fs.FileStorageModule', 'version': '1.2.7-rdg'},
#    {'name': 'org.opensilex.nosql.NoSQLModule', 'version': '1.2.7-rdg'},
#    {'name': 'org.opensilex.sparql.SPARQLModule', 'version': '1.2.7-rdg'},
# ...
